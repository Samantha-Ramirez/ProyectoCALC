# %% [markdown]
# $$ c = F y \\
# c = (c_0, \ldots, c_{n-1})^T \\
# y = (y_0, \ldots, y_{n-1})^T \\
# $$
# $$
# (7)\\
# c_j = \frac{1}{n} \sum_{k=0}^{n-1} y_k \omega^{jk}
# \quad j = 0, 1, \ldots, n-1\\
# \omega = e^{-2\pi i / n}
# $$
# $$
# c = \begin{bmatrix} 1/nw \end{bmatrix}\begin{bmatrix} y_0 \\ \vdots \\ y_{n-1} \end{bmatrix}
# $$
# Vector se puede expresar como un producto $ c = F y $, donde cada componente $ c_j $ es una combinación lineal de los $ y_k $, y los coeficientes de esta combinación están dados por los términos $ \frac{1}{n} \omega^{jk} $. $ F $ debe tener dimensiones $ n \times n $.
#
# $$
# (8)\\
# y_k = \sum_{j=0}^{n-1} c_j \overline \omega^{jk}
# \quad k = 0, 1, \ldots, n-1\\
# y_k = f(x_k) \\
# x_k = 2\pi k / n
# $$
#
# Cada elemento $ f_{jk} $ (fila $ j $, columna $ k $) representa el coeficiente que multiplica $ y_k $ para obtener $ c_j $. Comparando con la suma, el elemento $ f_{jk} $ es $ \frac{1}{n} \omega^{jk} $, ya que:
#
# $ c_j $ se calcula como $ c_j = \sum_{k=0}^{n-1} f_{jk} y_k $,
# Y de (7), $ c_j = \frac{1}{n} \sum_{k=0}^{n-1} y_k \omega^{jk} $.
#
# Por lo tanto, la matriz $ F = [f_{jk}] $ tiene entradas:
# $ f_{jk} = \frac{1}{n} \omega^{jk}, $
# donde $ j $ y $ k $ van de 0 a $ n-1 $.
#
# Matriz $ F $:
# La matriz $ F $ asociada a la transformación $ c = F y $ es la matriz de Fourier, definida como:
#
# Filas indexadas por $ j = 0, 1, \ldots, n-1 $,
# Columnas indexadas por $ k = 0, 1, \ldots, n-1 $,
# Elementos $ f_{jk} = \frac{1}{n} \omega^{jk} $, con $ \omega = e^{-2\pi i / n} $.
#
# Así, la matriz $ F $ se escribe como:
#
# $$  = \frac{1}{n} \begin{bmatrix}
# 1 & \omega & \omega^2 & \cdots & \omega^{n-1} \\
# 1 & \omega^2 & \omega^4 & \cdots & \omega^{2(n-1)} \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 1 & \omega^{n-1} & \omega^{2(n-1)} & \cdots & \omega^{(n-1)(n-1)}
# \end{bmatrix}.  $$
#
# ### Respuesta final:
# La matriz $$  F  $$ asociada a la transformación $$  c = F y  $$ es:
# $$  F = \frac{1}{n} \begin{bmatrix}
# 1 & \omega & \omega^2 & \cdots & \omega^{n-1} \\
# 1 & \omega^2 & \omega^4 & \cdots & \omega^{2(n-1)} \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 1 & \omega^{n-1} & \omega^{2(n-1)} & \cdots & \omega^{(n-1)(n-1)}
# \end{bmatrix},  $$
# donde $$  \omega = e^{-2\pi i / n}  $$.
