# %% [markdown]
# ![image.png](attachment:image.png)
#
# Por $(**)$ y por $(****)$ la matriz $ F^{-1} $ tiene elementos:
# $$(*****) \quad F^{-1} = [f^{-1}_{jk}] = [ n \cdot \frac{1}{n} \omega^{-jk}] =[ \omega^{-jk}]$$
#
# Si tenemos:
# $$
# (8)\quad y_k = f(x_k) = \sum_{j=0}^{n-1} c_j \overline{\omega}^{jk}
# $$
# Sustituyendo $\overline{\omega}^{jk} = \omega^{-jk}$.
# $$
# y_k = f(x_k) = \sum_{j=0}^{n-1} c_j \omega^{-jk}
# $$
# Usando $(*****)$ entonces conseguimos la siguiente expresión que finalmente se puede escribir matricialmente.
# $$
# y_k = \sum_{j=0}^{n-1} f^{-1}_{kj} c_j
# \\\implies y = F^{-1} c
# $$
